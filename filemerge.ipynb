# %%
import pandas as pd
import numpy as np
import datetime

# %%
data1 = pd.read_csv("data/JC-202102-citibike-tripdata.csv", error_bad_lines=False)
data2 = pd.read_csv("data/JC-202103-citibike-tripdata.csv", error_bad_lines=False)
data3= pd.read_csv("data/JC-202104-citibike-tripdata.csv", error_bad_lines=False)
data4= pd.read_csv("data/JC-202105-citibike-tripdata.csv", error_bad_lines=False)
data5= pd.read_csv("data/JC-202106-citibike-tripdata.csv", error_bad_lines=False)
data6= pd.read_csv("data/JC-202107-citibike-tripdata.csv", error_bad_lines=False)
data7= pd.read_csv("data/JC-202108-citibike-tripdata.csv", error_bad_lines=False) 
data8= pd.read_csv("data/JC-202109-citibike-tripdata.csv", error_bad_lines=False) 
data9= pd.read_csv("data/JC-202110-citibike-tripdata.csv", error_bad_lines=False)

# %%
data1["month"]="February"

# %%
data2["month"]="March"

# %%
data3["month"]="April"

# %%
data4["month"]="May"

# %%
data5["month"]="June"

# %%
data6["month"]="July"

# %%
data7["month"]="August"

# %%
data8["month"]="September"

# %%
data9["month"]="October"

# %%
data1[["started_at", "ended_at"]]= data1[["started_at", "ended_at"]].apply(pd.to_datetime)

# %%
data3.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# month                  object
# dtype: object

# %%
data3.columns.to_list()
# Out:
# ['ride_id',
#  'rideable_type',
#  'started_at',
#  'ended_at',
#  'start_station_name',
#  'start_station_id',
#  'end_station_name',
#  'end_station_id',
#  'start_lat',
#  'start_lng',
#  'end_lat',
#  'end_lng',
#  'member_casual',
#  'month']

# %%
citi_frames = [ data1, data2, data3, data4, data5, data6, data7, data8, data9]
citi_result = pd.concat(citi_frames)
citi_result
# Out:
#                 ride_id rideable_type           started_at  \
# 0      121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1      FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2      39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3      A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4      75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                 ...           ...                  ...
# 88757  2B1145DCE1C12234  classic_bike  2021-10-22 21:33:14
# 88758  9332D910D93C0961  classic_bike  2021-10-16 14:30:26
# 88759  9BD55309848AD745  classic_bike  2021-10-17 02:11:58
# 88760  263F1EE58709CB6D  classic_bike  2021-10-07 20:38:47
# 88761  2D38261C42BE80F3  classic_bike  2021-10-23 23:48:08
#
#                   ended_at          start_station_name start_station_id  \
# 0      2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1      2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
concatenated_df = citi_result.rename(columns={
   
 "ride_id": "Ride ID",
 "rideable_type": "Ridable Type",
 "started_at": "Started At",
 "ended_at": "Ended At",
 "start_station_name": "Start Station Name",
 "start_station_id": "Start Station ID",
 "end_station_name": "End Station Name",
 "end_station_id":"End Station ID",
 "start_lat":"Start Latitude",
 "start_lng":"Start Longtitude",
 "end_lat":"End Latitude",
 "end_lng":"End Longitude",
 "member_casual":"Member Casual",
 "month": "Month"
      
})

concatenated_df
# Out:
#                 Ride ID  Ridable Type           Started At  \
# 0      121DD7DD23CB1335   docked_bike  2021-02-03 23:11:28
# 1      FD73FB85F008349D   docked_bike  2021-02-27 16:34:05
# 2      39F9E6663CB5FDF6   docked_bike  2021-02-26 23:16:04
# 3      A64745CB0792EC6F   docked_bike  2021-02-24 16:51:50
# 4      75CC76EB9543764A   docked_bike  2021-02-24 20:44:16
# ...                 ...           ...                  ...
# 88757  2B1145DCE1C12234  classic_bike  2021-10-22 21:33:14
# 88758  9332D910D93C0961  classic_bike  2021-10-16 14:30:26
# 88759  9BD55309848AD745  classic_bike  2021-10-17 02:11:58
# 88760  263F1EE58709CB6D  classic_bike  2021-10-07 20:38:47
# 88761  2D38261C42BE80F3  classic_bike  2021-10-23 23:48:08
#
#                   Ended At          Start Station Name Start Station ID  \
# 0      2021-02-03 23:18:28  Hoboken Ave at Monmouth St            JC105
# 1      2021-02-27 16:56:40                Newport Pkwy            JC008
# ...

# %%
concatenated_df.dtypes
# Out:
# Ride ID                object
# Ridable Type           object
# Started At             object
# Ended At               object
# Start Station Name     object
# Start Station ID       object
# End Station Name       object
# End Station ID         object
# Start Latitude        float64
# Start Longtitude      float64
# End Latitude          float64
# End Longitude         float64
# Member Casual          object
# Month                  object
# dtype: object

# %%
concatenated_df.to_csv('Citi_Total_data.csv')
